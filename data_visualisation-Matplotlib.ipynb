# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks, yticks
from matplotlib.ticker import EngFormatter
matplotlib.rcParams['text.usetex'] = True
import scipy
import pandas as pd

import csv
from datetime import datetime
import matplotlib.pyplot as plt

# %%
x = [25,50,75,100] # debljina izolacije
y = [11.50, 22.99, 34.49, 45.98] # cijena
z = [50, 47, 46, 45] # decibeli
labels = [25,50,75,100]

fig, ax1 = plt.subplots()

ax1.set_title(r'Polystyrene', fontsize=18)
color = 'c'
ax1.set_xlabel(r'Debljina izolacije [mm]', fontsize=14 )
ax1.set_ylabel(r'Cijena izolacije [$\mathrm{\frac{kn}{m^2}}$]', color='black', fontsize=14)
#ax.set_xticks(labels)

locs, labels = yticks()      # služi za namještanje proizvoljnih labela, tickova
yticks([11.50, 22.99, 34.49, 45.98], ['11.50', '22.99', '34.49', '45.98'])

locs, labels = xticks()
xticks([25,50,75,100], ['25', '50', '75', '100'], fontsize=12)

ax1.bar(x, y, color=color, width=3)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)

#plt.legend(bbox_to_anchor=(1.15, 1),loc='upper left')

ax2 = ax1.twinx()  # inicira postavku desne osi 

color = 'crimson'
ax2.set_ylabel('Razina zvučnog tlaka [dB(A)]', color='black', fontsize=14)  # we already handled the x-label with ax1
ax2.plot(x, z, color=color,marker='8', linestyle='--', label='$N_{PP}$', linewidth=1.5)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12) # namjštanje paramatre tickova

plt.savefig('polystyrene.svg', format = 'svg', dpi=1200, bbox_inches='tight', pad_inches=0.1) # zadnje dvije naredbe služe da se namjesti bijeli prostor oko grafa
plt.show()

# %%
y1 = [92.50072906, 92.50072906, 90.65071448, 90.65071448, 75.54226207]

x1 = [0.4, 0.55, 0.7, 0.85, 1]


plt.plot(x1, y1, linestyle='--', marker='o', markersize='5', color='red',label='$y = - 327,37x^3 + 597,42x^2 - 353,96x + 159,74$'  )
plt.xlabel('$A_E/A_0$')
plt.ylabel('$n$ [o/min]')
plt.grid( linestyle='dashed')
plt.legend()
#plt.savefig('n.pdf', format = 'pdf', dpi=1200)
plt.show()

# %%
data = {'Polystyrene': [11.50, 22.99, 34.49, 45.98],
        'Rockwool': [11.17, 22.35, 33.52, 44.69],
        'Melamine': [8.6, 17.1, 25.79, 34.38],
        'Glass wool': [4.66, 9.32, 13.98, 18.64]
       }
df1 = pd.DataFrame(data,columns=['Polystyrene','Rockwool', 'Melamine', 'Glass wool'], index = ['25 mm','50 mm','75 mm','100 mm'])
plt.rcParams["figure.figsize"] = (11,5)
df1.plot.barh()

#plt.title('Store Inventory')
plt.ylabel('Debljina izolacijskog materijala')
plt.xlabel('Cijena izolacijskog materijal [kn/m2]')
#plt.savefig('usporedba.pdf', format = 'pdf', dpi=1200, bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
import matplotlib.font_manager
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Computer Modern Roman']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)


fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,4)
color = 'tab:red'


ax1.set_xlabel('Debljina izolacije [mm]',  fontsize=14 )
ax1.set_ylabel(r'Cijena izolacije [$\frac{kn}{m^2}$]', fontsize=14)
ax1.plot(x, data['Melamine'], color='b', marker='o', linestyle='--',label='Melamine')
ax1.plot(x, data['Glass wool'], color='r',marker='o',linestyle='--',label='Glass wool')
ax1.plot(x, data['Rockwool'], color='g',marker='o',linestyle='--',label='Rockwool')
ax1.plot(x,data['Polystyrene'], color='orange',marker='o',linestyle='--',label='Polystyrene')
ax1.tick_params(axis='y', labelcolor='black')


locs, labels = xticks()
xticks([25,50,75,100], ['25', '50', '75', '100'], fontsize=14)

locs, labels = yticks()
yticks(fontsize=14)
plt.legend(bbox_to_anchor=(0, 1),loc='upper left')




#plt.savefig('usporedba_new.svg', format = 'svg', dpi=1200, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
data_db = {'Polystyrene': [50, 47, 46, 45],
        'Rockwool': [49, 46, 44, 43],
        'Melamine': [49, 46, 45, 43],
        'Glass wool': [49, 46, 44, 43]
       }
df2 = pd.DataFrame(data_db,columns=['Polystyrene','Rockwool', 'Melamine', 'Glass wool'], index = ['25 ','50 ','75 ','100'])
plt.rcParams["figure.figsize"] = (11,8)
df2.plot.barh(color=['orange', 'green', 'blue', 'red'])   # pravi horizontalni bar chart
 
#plt.title('Store Inventory')
plt.ylabel('Debljina izolacijskog materijala [mm]', fontsize=14)
plt.xlabel('Razina zvučnog tlaka [dB(A)]', fontsize=14)
#plt.savefig('usporedba_dec.svg', format = 'svg', dpi=1200, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Create some mock data
x = [10.5,	11,	11.5,	12,	12.5]
y1l = [1603.28,	1853.35, 2130.39,2435.99, 2771.72]
y2l = [1923.94,	2224.02,	2556.47,	2923.18,	3326.07]
y1d = [84,	88,	92,96,	101]
y2d = [59.46,	62.30,	65.24,	68.23,	71.16]
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('$V_S$ [čv]' )
ax1.set_ylabel('$P_{Bpp}, P_{Bs}$ [kW]', color=color)
ax1.plot(x, y1l, color=color, marker='o', linestyle='--',label='$P_{Bpp}$')
ax1.plot(x,y2l, color=color,marker='s',linestyle='dotted',label='$P_{Bs}$')
ax1.tick_params(axis='y', labelcolor=color)
plt.legend(bbox_to_anchor=(1.15, 1),loc='upper left')

plt.grid()


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('$N_{PP}, N_S\; [min^{-1}]$ ', color=color)  # we already handled the x-label with ax1
ax2.plot(x, y1d, color=color,marker='+', linestyle='dotted', label='$N_{PP}$')
ax2.plot(x,y2d, color=color,marker='*', linestyle='--', label='$N_S$')
ax2.tick_params(axis='y', labelcolor=color)
plt.legend()
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.legend()
#plt.savefig('prognozni.pdf', format = 'pdf', dpi=1200)

plt.show()

# %%
x1 = [0.40,	0.55,	0.70,	0.85,	1.0]
y1 = [0.474121032,	0.470657419,	0.473758531,	0.481952884,	0.494422524]

x2 = [0.40,	0.55,	0.70,	0.85,	1.0]
y2 = [0.40,	0.55,	0.70,	0.85,	1.0]
plt.rcParams["figure.figsize"] = (7,4)
plt.plot(x1, y1, linestyle='--', marker='o', color='r', label='$(A_EA_0)_{kav}$')
plt.plot(x2, y2, linestyle='--',marker='s', label='$A_EA_0$')
plt.grid(linestyle='--')
plt.xlabel('$A_EA_0$')
plt.ylabel('$A_EA_0, (A_EA_0)_{kav}$')
plt.legend()

#plt.savefig('kavitacija.pdf', format = 'pdf', dpi=1200)
plt.show()

# %%
filename = 'sitka_weather_2018_simple.csv'

with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    # get dates and temperatures
    dates, highs, lowes = [],[], []
    for row in reader:
        date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        low = int(row[6])
        dates.append(date)
        highs.append(high)
        lowes.append(low)
        
        
        
# plot graph

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.5)
ax.plot(dates, lowes, c='blue', alpha=0.5)
plt.fill_between(dates, highs, lowes, facecolor='blue', alpha=0.1)

# style plot

plt.title("Daily high and low temperatures - 2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperatures (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
